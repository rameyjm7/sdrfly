# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import logging
import faulthandler
from concurrent.futures import ThreadPoolExecutor, as_completed
from sdrfly.sdr.sdr_simulated import SimulatedBluetoothSDR
from sdrfly.sdr.sdr_hackrf import HackRFSdr
from sdrfly.channelizers.channelizer_fft import ChannelizerFFT
from sdrfly.channelizers.channelizer_numba import ChannelizerNumba
from sdrfly.demodulators.demodulator_numba import GFSKDemodNumba
from sdrfly.utils import detect_peaks, extract_lap_and_access_code, probe_devices

# Enable faulthandler
faulthandler.enable()

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s.%(msecs)03d %(levelname)s %(message)s', datefmt='%Y-%m-%d %H:%M:%S')
logger = logging.getLogger(__name__)

# Suppress Numba debug output
import numba
numba_logger = logging.getLogger('numba')
numba_logger.setLevel(logging.WARNING)

# Load configuration from JSON file
config_path = '/home/dev/workspace/bluetooth-demod/src/sdrfly/config.json'
with open(config_path, 'r') as f:
    config = json.load(f)

START_FREQ = config["START_FREQ"]
END_FREQ = config["END_FREQ"]
STEP_FREQ = config["STEP_FREQ"]
SAMPLE_RATE = config["SAMPLE_RATE"]
BANDWIDTH = config["BANDWIDTH"]
NUM_SAMPLES = config["NUM_SAMPLES"]
PEAK_THRESHOLD = config["PEAK_THRESHOLD"]
GAIN = config["GAIN"]
NUM_CHANNELS = config["NUM_CHANNELS"]
NUM_THREADS = config["NUM_THREADS"]
TARGET_LAP = config["TARGET_LAP"]

def process_channel(channel_idx, ch_samples):
    logger.info(f"Processing channel {channel_idx + 1}")

    # Initialize GFSK demodulator
    gfsk_demod = GFSKDemodNumba(0.5)  # Adjust kf value as needed

    # Demodulate the signal using Numba
    demodulated_signal = gfsk_demod.demodulate(ch_samples)

    # Detect peaks in the demodulated signal
    peaks = detect_peaks(demodulated_signal, PEAK_THRESHOLD)

    if len(peaks) == 0:
        logger.debug(f"No peaks detected in channel {channel_idx + 1}.")
        return None

    logger.info(f"Detected peaks at indices: {peaks} in channel {channel_idx + 1}")
    lap_and_access_codes = extract_lap_and_access_code(demodulated_signal, peaks)
    
    for idx, (access_code, lap) in enumerate(lap_and_access_codes):
        logger.info(f"Channel {channel_idx + 1}, Peak {idx}: Access Code: {access_code}, LAP: {lap}")
        if lap == TARGET_LAP:
            logger.info(f"Found target LAP {TARGET_LAP} in channel {channel_idx + 1}!")
            return demodulated_signal, peaks

    return None

def main():
    # Probe for available devices
    probe_devices()

    # Initialize SDR (choose the appropriate SDR class)
    sdr = HackRFSdr(START_FREQ, SAMPLE_RATE, BANDWIDTH, GAIN)
    # sdr = SimulatedBluetoothSDR(START_FREQ, SAMPLE_RATE, BANDWIDTH, GAIN)

    # Initialize Channelizer
    channelizer = ChannelizerFFT(num_channels=NUM_CHANNELS, channel_bw=BANDWIDTH, sample_rate=SAMPLE_RATE)
    # You can switch between different channelizer methods by initializing with ChannelizerNumba
    
    found = False

    current_freq = START_FREQ

    while not found and current_freq <= END_FREQ:
        logger.info(f"Setting frequency to {current_freq / 1e6} MHz")
        sdr.set_frequency(current_freq)

        logger.info("Capturing wideband samples...")
        samples = sdr.capture_samples(NUM_SAMPLES)

        # Check if samples are captured correctly
        if not np.any(samples):
            logger.error("No samples captured. Please check the SDR connection and settings.")
            current_freq += STEP_FREQ
            continue

        # Channelize the wideband samples into multiple 1 MHz channels
        channel_samples = channelizer.channelize(samples)

        with ThreadPoolExecutor(max_workers=NUM_THREADS) as executor:
            future_to_channel = {executor.submit(process_channel, idx, ch_samples): idx for idx, ch_samples in enumerate(channel_samples)}

            for future in as_completed(future_to_channel):
                result = future.result()
                if result is not None:
                    demodulated_signal, peaks = result
                    found = True
                    break

        if not found:
            current_freq += STEP_FREQ

    if found:
        # Plot the demodulated signal of the last checked channel
        plt.figure(figsize=(12, 6))
        plt.plot(demodulated_signal)
        plt.plot(peaks, demodulated_signal[peaks], "x")
        plt.title('Demodulated Bluetooth Signal with Detected Peaks')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')
        plt.grid(True)
        plt.show()

    sdr.close()

# Run the main function for testing
if __name__ == '__main__':
    main()
# Out:
# [INFO] Opening HackRF One #0 88869dc2a59211b...
# 2024-06-29 11:03:14.305 INFO Setting frequency to 2407.0 MHz
# 2024-06-29 11:03:14.307 INFO Capturing wideband samples...
# Found device: {device=HackRF One, driver=hackrf, label=HackRF One #0 88869dc2a59211b, part_id=a000cb3c005d435b, serial=0000000000000000088869dc2a59211b, version=2021.03.1}
# 2024-06-29 11:03:14.915 ERROR No samples captured. Please check the SDR connection and settings.
# 2024-06-29 11:03:14.918 INFO Setting frequency to 2408.0 MHz
# 2024-06-29 11:03:14.923 INFO Capturing wideband samples...
# 2024-06-29 11:03:15.536 ERROR No samples captured. Please check the SDR connection and settings.
# 2024-06-29 11:03:15.540 INFO Setting frequency to 2409.0 MHz
# 2024-06-29 11:03:15.544 INFO Capturing wideband samples...
# 2024-06-29 11:03:16.157 ERROR No samples captured. Please check the SDR connection and settings.
# 2024-06-29 11:03:16.161 INFO Setting frequency to 2410.0 MHz
# 2024-06-29 11:03:16.165 INFO Capturing wideband samples...
# 2024-06-29 11:03:16.776 ERROR No samples captured. Please check the SDR connection and settings.
# 2024-06-29 11:03:16.777 INFO Setting frequency to 2411.0 MHz
# 2024-06-29 11:03:16.781 INFO Capturing wideband samples...
# 2024-06-29 11:03:17.721 INFO Processing channel 1
# 2024-06-29 11:03:20.066 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:20.069 INFO Setting frequency to 2412.0 MHz
# 2024-06-29 11:03:20.072 INFO Capturing wideband samples...
# 2024-06-29 11:03:20.684 ERROR No samples captured. Please check the SDR connection and settings.
# 2024-06-29 11:03:20.687 INFO Setting frequency to 2413.0 MHz
# 2024-06-29 11:03:20.692 INFO Capturing wideband samples...
# 2024-06-29 11:03:21.581 INFO Processing channel 1
# 2024-06-29 11:03:21.598 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:21.600 INFO Setting frequency to 2414.0 MHz
# 2024-06-29 11:03:21.604 INFO Capturing wideband samples...
# 2024-06-29 11:03:22.445 INFO Processing channel 1
# 2024-06-29 11:03:22.456 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:22.458 INFO Setting frequency to 2415.0 MHz
# 2024-06-29 11:03:22.461 INFO Capturing wideband samples...
# 2024-06-29 11:03:23.286 INFO Processing channel 1
# 2024-06-29 11:03:23.296 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:23.299 INFO Setting frequency to 2416.0 MHz
# 2024-06-29 11:03:23.303 INFO Capturing wideband samples...
# 2024-06-29 11:03:24.114 INFO Processing channel 1
# 2024-06-29 11:03:24.125 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:24.128 INFO Setting frequency to 2417.0 MHz
# 2024-06-29 11:03:24.131 INFO Capturing wideband samples...
# 2024-06-29 11:03:24.946 INFO Processing channel 1
# 2024-06-29 11:03:24.960 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:24.962 INFO Setting frequency to 2418.0 MHz
# 2024-06-29 11:03:24.966 INFO Capturing wideband samples...
# 2024-06-29 11:03:25.777 INFO Processing channel 1
# 2024-06-29 11:03:25.788 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:25.791 INFO Setting frequency to 2419.0 MHz
# 2024-06-29 11:03:25.792 INFO Capturing wideband samples...
# 2024-06-29 11:03:26.604 INFO Processing channel 1
# 2024-06-29 11:03:26.618 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:26.620 INFO Setting frequency to 2420.0 MHz
# 2024-06-29 11:03:26.623 INFO Capturing wideband samples...
# 2024-06-29 11:03:27.433 INFO Processing channel 1
# 2024-06-29 11:03:27.444 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:27.446 INFO Setting frequency to 2421.0 MHz
# 2024-06-29 11:03:27.452 INFO Capturing wideband samples...
# 2024-06-29 11:03:28.263 INFO Processing channel 1
# 2024-06-29 11:03:28.277 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:28.279 INFO Setting frequency to 2422.0 MHz
# 2024-06-29 11:03:28.283 INFO Capturing wideband samples...
# 2024-06-29 11:03:29.063 INFO Processing channel 1
# 2024-06-29 11:03:29.076 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:29.079 INFO Setting frequency to 2423.0 MHz
# 2024-06-29 11:03:29.081 INFO Capturing wideband samples...
# 2024-06-29 11:03:29.863 INFO Processing channel 1
# 2024-06-29 11:03:29.877 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:29.880 INFO Setting frequency to 2424.0 MHz
# 2024-06-29 11:03:29.883 INFO Capturing wideband samples...
# 2024-06-29 11:03:30.677 INFO Processing channel 1
# 2024-06-29 11:03:30.688 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:30.691 INFO Setting frequency to 2425.0 MHz
# 2024-06-29 11:03:30.694 INFO Capturing wideband samples...
# 2024-06-29 11:03:31.493 INFO Processing channel 1
# 2024-06-29 11:03:31.504 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:31.506 INFO Setting frequency to 2426.0 MHz
# 2024-06-29 11:03:31.509 INFO Capturing wideband samples...
# 2024-06-29 11:03:32.291 INFO Processing channel 1
# 2024-06-29 11:03:32.305 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:32.307 INFO Setting frequency to 2427.0 MHz
# 2024-06-29 11:03:32.309 INFO Capturing wideband samples...
# 2024-06-29 11:03:33.097 INFO Processing channel 1
# 2024-06-29 11:03:33.110 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:33.112 INFO Setting frequency to 2428.0 MHz
# 2024-06-29 11:03:33.115 INFO Capturing wideband samples...
# 2024-06-29 11:03:33.899 INFO Processing channel 1
# 2024-06-29 11:03:33.914 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:33.916 INFO Setting frequency to 2429.0 MHz
# 2024-06-29 11:03:33.918 INFO Capturing wideband samples...
# 2024-06-29 11:03:34.712 INFO Processing channel 1
# 2024-06-29 11:03:34.725 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:34.728 INFO Setting frequency to 2430.0 MHz
# 2024-06-29 11:03:34.731 INFO Capturing wideband samples...
# 2024-06-29 11:03:35.517 INFO Processing channel 1
# 2024-06-29 11:03:35.529 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:35.531 INFO Setting frequency to 2431.0 MHz
# 2024-06-29 11:03:35.533 INFO Capturing wideband samples...
# 2024-06-29 11:03:36.316 INFO Processing channel 1
# 2024-06-29 11:03:36.329 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:36.332 INFO Setting frequency to 2432.0 MHz
# 2024-06-29 11:03:36.335 INFO Capturing wideband samples...
# 2024-06-29 11:03:37.118 INFO Processing channel 1
# 2024-06-29 11:03:37.129 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:37.131 INFO Setting frequency to 2433.0 MHz
# 2024-06-29 11:03:37.133 INFO Capturing wideband samples...
# 2024-06-29 11:03:37.912 INFO Processing channel 1
# 2024-06-29 11:03:37.923 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:37.926 INFO Setting frequency to 2434.0 MHz
# 2024-06-29 11:03:37.928 INFO Capturing wideband samples...
# 2024-06-29 11:03:38.753 INFO Processing channel 1
# 2024-06-29 11:03:38.764 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:38.766 INFO Setting frequency to 2435.0 MHz
# 2024-06-29 11:03:38.768 INFO Capturing wideband samples...
# 2024-06-29 11:03:39.548 INFO Processing channel 1
# 2024-06-29 11:03:39.559 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:39.561 INFO Setting frequency to 2436.0 MHz
# 2024-06-29 11:03:39.565 INFO Capturing wideband samples...
# 2024-06-29 11:03:40.345 INFO Processing channel 1
# 2024-06-29 11:03:40.356 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:40.359 INFO Setting frequency to 2437.0 MHz
# 2024-06-29 11:03:40.361 INFO Capturing wideband samples...
# 2024-06-29 11:03:41.150 INFO Processing channel 1
# 2024-06-29 11:03:41.164 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:41.167 INFO Setting frequency to 2438.0 MHz
# 2024-06-29 11:03:41.169 INFO Capturing wideband samples...
# 2024-06-29 11:03:41.947 INFO Processing channel 1
# 2024-06-29 11:03:41.960 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:41.963 INFO Setting frequency to 2439.0 MHz
# 2024-06-29 11:03:41.967 INFO Capturing wideband samples...
# 2024-06-29 11:03:42.796 INFO Processing channel 1
# 2024-06-29 11:03:42.809 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:42.812 INFO Setting frequency to 2440.0 MHz
# 2024-06-29 11:03:42.814 INFO Capturing wideband samples...
# 2024-06-29 11:03:43.606 INFO Processing channel 1
# 2024-06-29 11:03:43.621 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:43.623 INFO Setting frequency to 2441.0 MHz
# 2024-06-29 11:03:43.626 INFO Capturing wideband samples...
# 2024-06-29 11:03:44.403 INFO Processing channel 1
# 2024-06-29 11:03:44.414 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:44.417 INFO Setting frequency to 2442.0 MHz
# 2024-06-29 11:03:44.420 INFO Capturing wideband samples...
# 2024-06-29 11:03:45.197 INFO Processing channel 1
# 2024-06-29 11:03:45.208 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:45.210 INFO Setting frequency to 2443.0 MHz
# 2024-06-29 11:03:45.212 INFO Capturing wideband samples...
# 2024-06-29 11:03:45.994 INFO Processing channel 1
# 2024-06-29 11:03:46.005 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:46.007 INFO Setting frequency to 2444.0 MHz
# 2024-06-29 11:03:46.011 INFO Capturing wideband samples...
# 2024-06-29 11:03:46.792 INFO Processing channel 1
# 2024-06-29 11:03:46.804 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:46.807 INFO Setting frequency to 2445.0 MHz
# 2024-06-29 11:03:46.809 INFO Capturing wideband samples...
# 2024-06-29 11:03:47.589 INFO Processing channel 1
# 2024-06-29 11:03:47.600 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:47.602 INFO Setting frequency to 2446.0 MHz
# 2024-06-29 11:03:47.605 INFO Capturing wideband samples...
# 2024-06-29 11:03:48.406 INFO Processing channel 1
# 2024-06-29 11:03:48.417 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:48.419 INFO Setting frequency to 2447.0 MHz
# 2024-06-29 11:03:48.421 INFO Capturing wideband samples...
# 2024-06-29 11:03:49.195 INFO Processing channel 1
# 2024-06-29 11:03:49.207 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:49.209 INFO Setting frequency to 2448.0 MHz
# 2024-06-29 11:03:49.212 INFO Capturing wideband samples...
# 2024-06-29 11:03:49.992 INFO Processing channel 1
# 2024-06-29 11:03:50.005 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:50.007 INFO Setting frequency to 2449.0 MHz
# 2024-06-29 11:03:50.010 INFO Capturing wideband samples...
# 2024-06-29 11:03:50.824 INFO Processing channel 1
# 2024-06-29 11:03:50.839 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:50.841 INFO Setting frequency to 2450.0 MHz
# 2024-06-29 11:03:50.844 INFO Capturing wideband samples...
# 2024-06-29 11:03:51.624 INFO Processing channel 1
# 2024-06-29 11:03:51.635 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:51.637 INFO Setting frequency to 2451.0 MHz
# 2024-06-29 11:03:51.641 INFO Capturing wideband samples...
# 2024-06-29 11:03:52.420 INFO Processing channel 1
# 2024-06-29 11:03:52.431 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:52.434 INFO Setting frequency to 2452.0 MHz
# 2024-06-29 11:03:52.438 INFO Capturing wideband samples...
# 2024-06-29 11:03:53.229 INFO Processing channel 1
# 2024-06-29 11:03:53.240 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:53.242 INFO Setting frequency to 2453.0 MHz
# 2024-06-29 11:03:53.244 INFO Capturing wideband samples...
# 2024-06-29 11:03:54.022 INFO Processing channel 1
# 2024-06-29 11:03:54.036 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:54.038 INFO Setting frequency to 2454.0 MHz
# 2024-06-29 11:03:54.040 INFO Capturing wideband samples...
# 2024-06-29 11:03:54.813 INFO Processing channel 1
# 2024-06-29 11:03:54.824 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:54.826 INFO Setting frequency to 2455.0 MHz
# 2024-06-29 11:03:54.829 INFO Capturing wideband samples...
# 2024-06-29 11:03:55.602 INFO Processing channel 1
# 2024-06-29 11:03:55.616 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:55.619 INFO Setting frequency to 2456.0 MHz
# 2024-06-29 11:03:55.621 INFO Capturing wideband samples...
# 2024-06-29 11:03:56.400 INFO Processing channel 1
# 2024-06-29 11:03:56.410 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:56.413 INFO Setting frequency to 2457.0 MHz
# 2024-06-29 11:03:56.416 INFO Capturing wideband samples...
# 2024-06-29 11:03:57.191 INFO Processing channel 1
# 2024-06-29 11:03:57.202 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:57.205 INFO Setting frequency to 2458.0 MHz
# 2024-06-29 11:03:57.207 INFO Capturing wideband samples...
# 2024-06-29 11:03:58.024 INFO Processing channel 1
# 2024-06-29 11:03:58.035 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:58.037 INFO Setting frequency to 2459.0 MHz
# 2024-06-29 11:03:58.041 INFO Capturing wideband samples...
# 2024-06-29 11:03:58.819 INFO Processing channel 1
# 2024-06-29 11:03:58.835 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:58.837 INFO Setting frequency to 2460.0 MHz
# 2024-06-29 11:03:58.841 INFO Capturing wideband samples...
# 2024-06-29 11:03:59.635 INFO Processing channel 1
# 2024-06-29 11:03:59.646 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:03:59.648 INFO Setting frequency to 2461.0 MHz
# 2024-06-29 11:03:59.652 INFO Capturing wideband samples...
# 2024-06-29 11:04:00.450 INFO Processing channel 1
# 2024-06-29 11:04:00.460 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:00.463 INFO Setting frequency to 2462.0 MHz
# 2024-06-29 11:04:00.467 INFO Capturing wideband samples...
# 2024-06-29 11:04:01.248 INFO Processing channel 1
# 2024-06-29 11:04:01.259 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:01.261 INFO Setting frequency to 2463.0 MHz
# 2024-06-29 11:04:01.265 INFO Capturing wideband samples...
# 2024-06-29 11:04:02.044 INFO Processing channel 1
# 2024-06-29 11:04:02.056 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:02.058 INFO Setting frequency to 2464.0 MHz
# 2024-06-29 11:04:02.062 INFO Capturing wideband samples...
# 2024-06-29 11:04:02.836 INFO Processing channel 1
# 2024-06-29 11:04:02.847 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:02.849 INFO Setting frequency to 2465.0 MHz
# 2024-06-29 11:04:02.852 INFO Capturing wideband samples...
# 2024-06-29 11:04:03.631 INFO Processing channel 1
# 2024-06-29 11:04:03.643 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:03.645 INFO Setting frequency to 2466.0 MHz
# 2024-06-29 11:04:03.648 INFO Capturing wideband samples...
# 2024-06-29 11:04:04.428 INFO Processing channel 1
# 2024-06-29 11:04:04.439 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:04.441 INFO Setting frequency to 2467.0 MHz
# 2024-06-29 11:04:04.446 INFO Capturing wideband samples...
# 2024-06-29 11:04:05.251 INFO Processing channel 1
# 2024-06-29 11:04:05.261 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:05.263 INFO Setting frequency to 2468.0 MHz
# 2024-06-29 11:04:05.265 INFO Capturing wideband samples...
# 2024-06-29 11:04:06.040 INFO Processing channel 1
# 2024-06-29 11:04:06.051 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:06.053 INFO Setting frequency to 2469.0 MHz
# 2024-06-29 11:04:06.056 INFO Capturing wideband samples...
# 2024-06-29 11:04:06.833 INFO Processing channel 1
# 2024-06-29 11:04:06.843 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:06.846 INFO Setting frequency to 2470.0 MHz
# 2024-06-29 11:04:06.850 INFO Capturing wideband samples...
# 2024-06-29 11:04:07.629 INFO Processing channel 1
# 2024-06-29 11:04:07.640 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:07.643 INFO Setting frequency to 2471.0 MHz
# 2024-06-29 11:04:07.647 INFO Capturing wideband samples...
# 2024-06-29 11:04:08.428 INFO Processing channel 1
# 2024-06-29 11:04:08.444 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:08.447 INFO Setting frequency to 2472.0 MHz
# 2024-06-29 11:04:08.450 INFO Capturing wideband samples...
# 2024-06-29 11:04:09.226 INFO Processing channel 1
# 2024-06-29 11:04:09.240 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:09.242 INFO Setting frequency to 2473.0 MHz
# 2024-06-29 11:04:09.244 INFO Capturing wideband samples...
# 2024-06-29 11:04:10.020 INFO Processing channel 1
# 2024-06-29 11:04:10.030 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:10.032 INFO Setting frequency to 2474.0 MHz
# 2024-06-29 11:04:10.036 INFO Capturing wideband samples...
# 2024-06-29 11:04:10.814 INFO Processing channel 1
# 2024-06-29 11:04:10.828 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:10.830 INFO Setting frequency to 2475.0 MHz
# 2024-06-29 11:04:10.833 INFO Capturing wideband samples...
# 2024-06-29 11:04:11.611 INFO Processing channel 1
# 2024-06-29 11:04:11.626 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:11.628 INFO Setting frequency to 2476.0 MHz
# 2024-06-29 11:04:11.630 INFO Capturing wideband samples...
# 2024-06-29 11:04:12.408 INFO Processing channel 1
# 2024-06-29 11:04:12.419 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:12.421 INFO Setting frequency to 2477.0 MHz
# 2024-06-29 11:04:12.425 INFO Capturing wideband samples...
# 2024-06-29 11:04:13.217 INFO Processing channel 1
# 2024-06-29 11:04:13.228 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:13.229 INFO Setting frequency to 2478.0 MHz
# 2024-06-29 11:04:13.233 INFO Capturing wideband samples...
# 2024-06-29 11:04:14.034 INFO Processing channel 1
# 2024-06-29 11:04:14.048 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:14.050 INFO Setting frequency to 2479.0 MHz
# 2024-06-29 11:04:14.053 INFO Capturing wideband samples...
# 2024-06-29 11:04:14.835 INFO Processing channel 1
# 2024-06-29 11:04:14.845 DEBUG No peaks detected in channel 1.
# 2024-06-29 11:04:14.848 INFO Setting frequency to 2480.0 MHz
# 2024-06-29 11:04:14.852 INFO Capturing wideband samples...
# 2024-06-29 11:04:15.632 INFO Processing channel 1
# 2024-06-29 11:04:15.644 DEBUG No peaks detected in channel 1.
